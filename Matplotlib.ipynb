# %% [markdown]
# # LinePlot

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\ML\Numpy Stack\Mtplotlib.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/ML/Numpy%20Stack/Mtplotlib.ipynb#ch0000001?line=0'>1</a> import numpy as np
#       <a href='vscode-notebook-cell:/d%3A/ML/Numpy%20Stack/Mtplotlib.ipynb#ch0000001?line=1'>2</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
x = np.linspace(0, 20, 1000)

# %%
y = np.sin(x) + 0.2 * x

# %%
plt.plot(x, y)
plt.xlabel("Input")
plt.ylabel("Output")
plt.title("Title");

# %% [markdown]
# #  ScatterPlot

# %%
x = np.random.randn(100, 2)
plt.scatter(x[:, 0], x[:, 1]);

# %%
x = np.random.randn(200, 2)
x[: 100] += 3
y = np.zeros(200)
y[:  100] = 1
plt.scatter(x[:, 0], x[:, 1], c=y)

# %% [markdown]
# # Histogram

# %%
x  =  np.random.randn(10000)

# %%
plt.hist(x, bins=50);

# %% [markdown]
# # Images

# %%
from PIL import Image
import cv2

# %%
im  = Image.open('blue.jpg')
img = cv2.imread('blue.jpg')

# %%
type(im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\ML\Numpy Stack\Mtplotlib.ipynb Cell 18' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/ML/Numpy%20Stack/Mtplotlib.ipynb#ch0000017?line=0'>1</a> plt.imshow(img)
#
# NameError: name 'plt' is not defined
